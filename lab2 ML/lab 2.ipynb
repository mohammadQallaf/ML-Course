# %%
import pandas as pd

df = pd.read_excel("toyota_cars.xlsx")
print("Shape of the dataset:", df.shape)
# Out:
# Shape of the dataset: (33, 14)

# %%
print("\nFirst 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#            model    price             dimensions wheelbase seats  \
# 0          Camry  2355000  4,885 x 1,840 x 1,445         -     5
# 1  Corolla Altis  1302000  4,630 x 1,780 x 1,435      2700     5
# 2       GR Yaris  2740000  3,995 x 1,805 x 1,455      2560     4
# 3          Prius  2436000  4,480 x 1,745 x 1,480      2700     5
# 4           Vios   985000  4,425 x 1,730 x 1,475      2550     5
#
#                                          engine_type  engine_displacement  \
# 0  16-Valve DOHC, 4-Cylinder, In-line, VVT-iE (In...                 2487
# 1      Dual VVT-I, 4-Cylinder In-Line DOHC, 16 Valve                 1598
# 2    3-Cylinder, In-line, DOHC 4-Valve Roller-rocker                 1618
# 3  Hybrid Synergy Drive, Variable Valve Timing - ...                 1786
# 4         Dual VVT-I, 4-Cylinder In-LineDOHC 16V EFI                 1496
#
#             max_ouput           max_torque fuel  \
# 0          178 / 5700  221 / 3,600 ~ 5,200  50L
# ...

# %%
print("\nColumn names and data types:")
print(df.dtypes)
# Out:
# Column names and data types:
# model                     str
# price                   int64
# dimensions                str
# wheelbase              object
# seats                  object
# engine_type               str
# engine_displacement     int64
# max_ouput                 str
# max_torque             object
# fuel                   object
# power_transmission        str
# brake                     str
# tires                  object
# wheels_size               str
# dtype: object
